# %%
import torch

# %%
torch.__version__
# Out:
# '2.2.1'

# %%
# !nvidia-smi
# Out:
# Tue Feb 27 21:40:35 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.61                 Driver Version: 551.61         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650 Ti   WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   44C    P8              3W /   50W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
print(torch.cuda.is_available()) # cuda is enabled
# Out:
# True

# %%
torch.cuda.device_count() # it has only 1 gpu core
# Out:
# 1

# %% [markdown]
# #### By default the tensor generated by the torch is cpu

# %%
cpu_tensor = torch.tensor([1,2,3])
print(cpu_tensor, cpu_tensor.device)
# Out:
# tensor([1, 2, 3]) cpu

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
gpu_tensor = torch.tensor([1,2,3,4], device=device)
print(gpu_tensor, gpu_tensor.device)
# Out:
# tensor([1, 2, 3, 4], device='cuda:0') cuda:0
